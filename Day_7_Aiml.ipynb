# %%
# STEP 1: IMPORT REQUIRED LIBRARIES


import pandas as pd
import numpy as np

# train_test_split is used to divide the dataset into training and testing parts

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler


# LabelEncoder converts target labels into numbers
# StandardScaler performs standardization
# MinMaxScaler performs normalization

# %%
# STEP 2: LOAD THE CSV FILE FROM GITHUB

import io

# The user provided the raw CSV content directly as a string.
csv_data = """PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/5 21171,7.25,,S
2,1,1,"Cumings, Mrs. John Bradley",female,38,1,0,PC 17599,71.2833,C85,C
3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,STON/O2. 3101282,7.925,,S
4,1,1,"Futrelle, Mrs. Jacques Heath",female,35,1,0,113803,53.1,C123,S
5,0,3,"Allen, Mr. William Henry",male,35,0,0,373450,8.05,,S
6,0,3,"Moran, Mr. James",male,,0,0,330877,8.4583,,Q
7,0,1,"McCarthy, Mr. Timothy J",male,54,0,0,17463,51.8625,E46,S
8,0,3,"Palsson, Master. Gosta Leonard",male,2,3,1,349909,21.075,,S
9,1,3,"Johnson, Mrs. Oscar W",female,27,0,2,347742,11.1333,,S
10,1,2,"Nasser, Mrs. Nicholas",female,14,1,0,237736,30.0708,,C
11,1,3,"Sandstrom, Miss. Marguerite",female,4,1,1,PP 9549,16.7,G6,S
12,1,1,"Bonnell, Miss. Elizabeth",female,58,0,0,113783,26.55,C103,S
13,0,3,"Saundercock, Mr. William Henry",male,20,0,0,A/5. 2151,8.05,,S
14,0,3,"Andersson, Mr. Anders Johan",male,39,1,5,347082,31.275,,S
15,0,3,"Vestrom, Miss. Hulda Amanda",female,14,0,0,350406,7.8542,,S
16,1,2,"Hewlett, Mrs. Mary D",female,55,0,0,248706,16.0,,S
17,0,3,"Rice, Master. Eugene",male,2,4,1,382652,29.125,,Q
18,1,2,"Williams, Mr. Charles Eugene",male,,0,0,244373,13.0,,S
19,0,3,"Vander Planke, Mrs. Julius",female,31,1,0,345763,18.0,,S
20,1,3,"Masselmani, Mrs. Fatima",female,,0,0,2649,7.225,,C
21,0,2,"Fynney, Mr. Joseph J",male,35,0,0,239865,26.0,,S
22,1,2,"Beesley, Mr. Lawrence",male,34,0,0,248698,13.0,D56,S
23,1,3,"McGowan, Miss. Anna",female,15,0,0,330923,8.0292,,Q
24,0,1,"Sloper, Mr. William Thompson",male,28,0,0,113788,35.5,A6,S
25,0,3,"Palsson, Miss. Torborg Danira",female,8,3,1,349909,21.075,,S
26,1,3,"Asplund, Mrs. Carl Oscar",female,38,1,5,347077,31.3875,,S
27,0,3,"Emir, Mr. Farred Chehab",male,,0,0,2631,7.225,,C
28,0,1,"Fortune, Mr. Charles Alexander",male,19,3,2,19950,263.0,C23 C25 C27,S
29,1,3,"O'Dwyer, Miss. Ellen",female,,0,0,330959,7.8792,,Q
30,0,3,"Todoroff, Mr. Lalio",male,,0,0,349216,7.8958,,S
31,0,2,"Meyer, Mr. Edgar Joseph",male,29,0,0,248723,21.0,,S
32,1,1,"Silvey, Mrs. William Baird",female,50,1,0,13507,55.9,E44,S
33,0,3,"Madsen, Mr. Fridtjof Arne",male,24,0,0,C 17369,7.4958,,S
34,1,2,"Nye, Miss. Elizabeth",female,18,0,1,231919,23.0,,S
35,0,3,"Petroff, Mr. Pastcho",male,26,0,0,349215,7.8958,,S
36,1,1,"Astor, Mrs. John Jacob",female,18,1,0,PC 17757,227.525,B77,C
37,0,3,"Kraeff, Mr. Theodor",male,25,0,0,349253,7.925,,S
38,1,2,"Collyer, Mrs. Harvey",female,30,1,1,C.A. 31921,26.25,,S
39,0,3,"Canavan, Miss. Mary",female,,0,0,364858,7.75,,Q
40,1,1,"Harper, Mr. Henry Sleeper",male,48,1,0,PC 17572,76.7292,D33,C"""

# Read the CSV data from the string into a pandas DataFrame
df = pd.read_csv(io.StringIO(csv_data))

# Display the first 5 rows to confirm it's loaded correctly
display(df.head())
# Out:
#    PassengerId  Survived  Pclass                          Name     Sex   Age  \
# 0            1         0       3       Braund, Mr. Owen Harris    male  22.0
# 1            2         1       1    Cumings, Mrs. John Bradley  female  38.0
# 2            3         1       3        Heikkinen, Miss. Laina  female  26.0
# 3            4         1       1  Futrelle, Mrs. Jacques Heath  female  35.0
# 4            5         0       3      Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
# STEP 3: DISPLAY THE FIRST 5 ROWS

# head() shows the first 5 rows by default
# This helps us quickly understand what the dataset looks like

print("First 5 rows of dataset:")
display(df.head())
# Out:
# First 5 rows of dataset:
#    PassengerId  Survived  Pclass                          Name     Sex   Age  \
# 0            1         0       3       Braund, Mr. Owen Harris    male  22.0
# 1            2         1       1    Cumings, Mrs. John Bradley  female  38.0
# 2            3         1       3        Heikkinen, Miss. Laina  female  26.0
# 3            4         1       1  Futrelle, Mrs. Jacques Heath  female  35.0
# 4            5         0       3      Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
# STEP 4: CHECK THE SHAPE OF THE DATASET

print("\nDataset shape:")
print(df.shape)

# shape returns (rows, columns)
# It tells us how many records and features are present
# Out:
# Dataset shape:
# (40, 12)

# %%
# STEP 5: DISPLAY ALL COLUMN NAMES

print("\nColumn names:")
print(df.columns)

# columns shows the names of all dataset columns
# This is useful to know which features are available
# Out:
# Column names:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# STEP 6: CHECK BASIC INFORMATION ABOUT THE DATASET

print("\nDataset info: ")
df.info()

# info() gives:
# - total number of rows
# - column names
# - data types
# - non-null values
# This helps us detect missing values and data types
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  40 non-null     int64
#  1   Survived     40 non-null     int64
#  2   Pclass       40 non-null     int64
#  3   Name         40 non-null     object
#  4   Sex          40 non-null     object
#  5   Age          33 non-null     float64
#  6   SibSp        40 non-null     int64
#  7   Parch        40 non-null     int64
#  8   Ticket       40 non-null     object
#  9   Fare         40 non-null     float64
#  10  Cabin        11 non-null     object
#  11  Embarked     40 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 3.9+ KB

# %%
# STEP 7: CHECK MISSING VALUES

print("\nMissing values before cleaning:")
print(df.isnull().sum())

# isnull() checks whether each value is missing
# sum() counts total missing values column-wise
# Out:
# Missing values before cleaning:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             7
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin          29
# Embarked        0
# dtype: int64

# %%
# STEP 8: DROP UNNECESSARY COLUMNS

# These columns are not very useful for this beginner-level preprocessing project:
# Cabin        -> too many missing values
# Name         -> text column, not directly useful for this basic model
# Ticket       -> mostly unique text values
# PassengerId  -> just an ID, not a predictive feature

drop_cols =["Cabin", "Name", "Ticket", "PassengerId"]

# some datasets may not contain all columns
# So we keep only those columns that actually exist in the DataFrame

existing_drop_cols =[col for col in drop_cols if col in df.columns]

# Drop the selected unnecessary columns
df.drop(columns=existing_drop_cols, inplace=True)

print("\nColumns after dropping unnecessary features:")
print(df.columns)
# Out:
# Columns after dropping unnecessary features:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
# STEP 9: HANDLE MISSING VALUES

# Fill missing values in Age with the median
# Median is used because it is better than mean when outliers may exist

if "Age" in df.columns:
  df["Age"] = df["Age"].fillna(df["Age"].median())

# Fill missing values in Embarked with the mode
# Mode means the most frequent value in that column

if "Embarked" in df.columns:
  df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode([0]))

print("\nCheck Missing values after cleaning:")
print(df.isnull().sum())
# Out:
# Check Missing values after cleaning:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# STEP 10: SEPARATE FEATURES (X) AND TARGET (y)

# X contains the input features used for prediction
# y contains the output/target column that we want to predict
# Here, Survived is the target column

X = df.drop(columns=["Survived"])
y = df["Survived"]

print("\nInput features (X) preview:")
display(X.head())

print("\nTarget variable (y) preview:")
display(y.head())
# Out:
# Input features (X) preview:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S
# Target variable (y) preview:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# STEP 11: APPLY ONE-HOT ENCODING TO CATEGORICAL INPUT COLUMNS

# Machine learning models work better with numeric data
# Columns like Sex and Embarked contain text values
# So we convert them into numeric format using one-hot encoding

# We only encode columns if they exist in the dataset

categorical_cols = [col for col in ["Sex", "Embarked"] if col in X.columns]


# pd.get_dummies() creates separate binary columns for each category
# drop_first=True removes one column from each category group
# This helps avoid redundant information

X = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

print("\nData after one-hot encoding:")
display(X.head())

print("\nColumns after one-hot encoding:")
print(X.columns)
# Out:
# Data after one-hot encoding:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S
# 0       3  22.0      1      0   7.2500      True       False        True
# 1       1  38.0      1      0  71.2833     False       False       False
# 2       3  26.0      0      0   7.9250     False       False        True
# 3       1  35.0      1      0  53.1000     False       False        True
# 4       3  35.0      0      0   8.0500      True       False        True
# Columns after one-hot encoding:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
# STEP 12: APPLY LABEL ENCODING TO THE TARGET COLUMN

# Label encoding converts class labels into numbers
# In this dataset, Survived is already 0 and 1 in most cases,
# but we still do this for teaching purposes

label_encoder =LabelEncoder()

y_encoded = label_encoder.fit_transform(y)

print("\nEncoded target values:")
print(y_encoded[:10])
# Out:
# Encoded target values:
# [0 1 1 1 0 0 0 0 1 1]

# %%
# STEP 13: SPLIT DATA INTO TRAINING AND TESTING SETS

# train_test_split divides the data into:
# - training data: used to train the model
# - testing data: used to evaluate the model

# test_size=0.2 means 20% data goes to testing, 80% to training
# random_state=42 ensures the split stays the same every time we run the code

X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size = 0.2, random_state=42
)

print("\nTrain-Test Split Shapes:")
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# Train-Test Split Shapes:
# X_train: (32, 8)
# X_test: (8, 8)
# y_train: (32,)
# y_test: (8,)

# %%
# Step 14: apply standardization

# Standardization changes the data so that:
# - mean becomes 0
# - standard deviation becomes 1
# This is useful when features have different ranges

# Create StandardScaler object

standard_scaler = StandardScaler()

# fit_transform() is used on training data:
# - fit() learns the mean and standard deviation from training data
# - transform() applies the scaling

X_train_standardized = standard_scaler.fit_transform(X_train)

# Only transform() is used on test data
# We do NOT fit again on test data
# This avoids data leakage

X_test_standardized = standard_scaler.transform(X_test)

print("\nFirst 5 rows after standardization:")
print(X_train_standardized[:5])
# Out:
# First 5 rows after standardization:
# [[-1.55236467e+00  1.54015802e+00  5.93390829e-01 -4.00000000e-01
#    1.16262334e+00  1.06458129e+00 -3.77964473e-01 -1.73205081e+00]
#  [-1.55236467e+00  2.00148460e+00 -6.72509606e-01 -4.00000000e-01
#    5.43307833e-01  1.06458129e+00 -3.77964473e-01  5.77350269e-01]
#  [ 8.13143398e-01  7.71280379e-01  5.93390829e-01  3.60000000e+00
#    3.33694436e-02 -9.39336437e-01 -3.77964473e-01  5.77350269e-01]
#  [-3.69610635e-01 -1.07402595e+00  5.93390829e-01 -4.00000000e-01
#    5.76482547e-04 -9.39336437e-01 -3.77964473e-01 -1.73205081e+00]
#  [ 8.13143398e-01  8.48168143e-01  5.93390829e-01  3.60000000e+00
#    3.05675843e-02  1.06458129e+00 -3.77964473e-01  5.77350269e-01]]

# %%
# STEP 15: APPLY NORMALIZATION

# Normalization scales the values into a fixed range, usually 0 to 1
# This is useful when we want all features to be on the same scale

# Create MinMaxScaler object
minmax_scaler= MinMaxScaler()

# Fit and transform training data
X_train_normalized = minmax_scaler.fit_transform(X_train)

# Transform test data using the same scaler
X_test_normalized = minmax_scaler.transform(X_test)

print("\nFirst 5 rows after normalization:")
print(X_train_normalized[:5])
# Out:
# First 5 rows after normalization:
# [[0.         0.82142857 0.33333333 0.         0.31542027 1.
#   0.         0.        ]
#  [0.         0.92857143 0.         0.         0.20253093 1.
#   0.         1.        ]
#  [1.         0.64285714 0.33333333 1.         0.10957894 0.
#   0.         1.        ]
#  [0.5        0.21428571 0.33333333 0.         0.10360141 0.
#   0.         0.        ]
#  [1.         0.66071429 0.33333333 1.         0.10906821 1.
#   0.         1.        ]]

# %%
# STEP 16: FINAL SUMMARY

print("\nProject completed successfully!")

print("\nTopics Covered:")
print("1. Data fetching from GitHub")
print("2. Data cleaning")
print("3. Handling missing values")
print("4. One-hot encoding")
print("5. Label encoding")
print("6. Train-test split")
print("7. Standardization")
print("8. Normalization")
# Out:
# Project completed successfully!
#
# Topics Covered:
# 1. Data fetching from GitHub
# 2. Data cleaning
# 3. Handling missing values
# 4. One-hot encoding
# 5. Label encoding
# 6. Train-test split
# 7. Standardization
# 8. Normalization
